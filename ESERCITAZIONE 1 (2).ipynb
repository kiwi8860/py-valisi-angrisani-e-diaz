# %% [markdown]
# ### ESERCITAZIONE 1: Introduzione a py

# %%
2+3

# %%
9-6

# %%
4*3

# %%
5/2

# %%
print ("Scemo chi legge")

# %% [markdown]
# #### Esercitazione

# %%
print ("ciao mondo!")

# %% [markdown]
# ##### Creiamo una cella da riempire con un dato :D

# %%
nome = input ("inserisci nome ")
print ("Ciao,", nome, "!")

# %% [markdown]
# ##### Facciamo la stessa cosa ma ripetuta 5 volte come se stessi parlando con un ragazzo speciale

# %%
nome = input ("CoMe Ti ChIamI?!??!")
for i in range(5):
    print("CiAo,", nome,"!")

# %% [markdown]
# ##### Mo diamoci alla matematica (facciamo una calcolatrice)

# %%
numero1 = int(input("inserisci un numero: "))
numero2 = int(input("inserisci un numero: "))
somma = numero1 + numero2
print("La somma è:", somma)

# %% [markdown]
# Nice

# %% [markdown]
# ##### Proviamo qualcosa di più divertente (e verosimile)

# %%
numero1 = int(input("inserisci il numero di persone che ti hanno rotto il cazzo oggi: "))
numero2 = int(input("inserisci il numero di persone che ti hanno rotto il cazzo ieri: "))
somma = numero1 + numero2
print("Quindi ho mandato dei sicari per uccidere", somma,"persone")

# %% [markdown]
# ##### Print numero da 1 a 10

# %%
for numero in range (1,11):
    print(numero)

# %% [markdown]
# ##### Sole

# %%
nome = input ("Ehi come ti chiami?")
print("ok,", nome, "va bhe me ne frega un cazzo comunque tua madre pesa più del sole")

# %% [markdown]
# ##### Luna

# %%
for numero in range (1,101): print (numero)

# %% [markdown]
# ###### ALTRO

# %%
operazione=input("inserisci un simbolo di un'operazione (+,-,*,/): ")

numero1 =float(input("inserisci un numero "))
numero2 =float(input("inserisci un altro numero "))

if operazione == "+":
    risultato = numero1 + numero2
    
elif operazione == "-":
        risultato = numero1 - numero2
        
elif operazione == "*":
        risultato = numero1 * numero2
        
elif operazione == "/":
        risultato = numero1 / numero2

else:
    rusultato = ("operazione non valida")
    
print ("Il risultato è:", risultato)

# %% [markdown]
# a

# %%
n =int(input("inserisci un numero intero positivo "))
somma=0


for numero in range(1,n+1):
    somma += numero

print("La somma dei primi", n, "numeri interi è:", somma)

# %% [markdown]
# b

# %%
n = int(input("inserisci un numero intero positivo: "))

print("quadrati dei primi", n, "numeri:")

for numero in range (1, n+1):
    quadrato = numero ** 2
print("il quadrati dei:", numero, "è:", quadrato)
# Out:
# inserisci un numero intero positivo: 7
# quadrati dei primi 7 numeri:
# il quadrati dei: 7 è: 49

# %% [markdown]
# c

# %%
numero = int(input("Inserisci un numero:"))

if numero % 2 == 0:
    print (numero, "è un numero pari.")
    
else:
    print(numero, "è un numero dispari.")

# %% [markdown]
# ##### Calcoliamo proteine

# %%
cane=int(input("quanti kg pesa il tuo cane? "))

if cane<=40:
    print("il tuo cane pesa solo", cane,"kg splah può mangiarlo in un solo pasto")
elif 40<cane<=60:
    print("il tuo cane pesa:", cane, "kg splash può mangiarlo in due pasti")
else:
    print("il tuo cane è molto pesante:", cane, "sarà una battaglia leggendaria (vincerà Splash)")

# %% [markdown]
# ##### gatto

# %%
gatto=str(input("come sta il tuo gatto? "))

if gatto=="bene":
    print("ne godo")
elif gatto=="male":
    print("male devi curare meglio il tuo gatto se non lo fai prenderò provvedimenti (rapirti il gatto)")
elif gatto!="bene""male":
    print("bastardo suka blyad nakhuy BENE O MALE")

carezza=str(input("posso accarezzarlo? "))
if carezza=="no":
    print("sei più inutile delle citure per i maranza")
elif carezza=="si":
    print("ok grazie")
elif carezza!="no""si":
    print("rincoglionito bastardo, o non sai scrivere o hai scritto parole sbagliate, QUESTA E' UNA DOMANDA: SI O NO")

# %% [markdown]
# #### Fattoriale

# %%
n = int(input("inserisci un numero:"))
fattoriale = 1

for numero in range(1, n+1):
    fattoriale *= numero
print("il fattoriale di", n," è:", fattoriale)
# Out:
# inserisci un numero:1558
# il fattoriale di 1558  è: ...

# %% [markdown]
# Lista

# %%
L = []

n = int(input("Quanti numeri vuoi inserire? "))

for i in range(n):
    numero = float(input("inserisci un numero:"))
    L.append(numero)

media = sum(L) / len(L)

print("media è:", media,"la lista completa è:", L)
# Out:
# Quanti numeri vuoi inserire? 4
# inserisci un numero:2
# inserisci un numero:4
# inserisci un numero:2
# inserisci un numero:4
# media è: 3.0 la lista completa è: [2.0, 4.0, 2.0, 4.0]

# %%
import random

numero_da_indovinare=random.randint(1, 100)
tentativi=0

while True:
    tentativo=int(input("indovina il numero (1-100): "))
    tentativi+=1

    if tentativo==numero_da_indovinare:
        print("Bravo! Hai indovinato il numero", numero_da_indovinare, "in", tentativi, "tentativi.")
        break
    elif tentativo<numero_da_indovinare:
        print("il numero da indovinare è più grande.")
    else:
        print("il numero da indovinare è più piccolo.")
# Out:
# indovina il numero (1-100): 34
# il numero da indovinare è più grande.
# indovina il numero (1-100): 67
# il numero da indovinare è più grande.
# indovina il numero (1-100): 89
# il numero da indovinare è più grande.
# indovina il numero (1-100): 94
# il numero da indovinare è più piccolo.
# indovina il numero (1-100): 92
# il numero da indovinare è più piccolo.
# indovina il numero (1-100): 91
# il numero da indovinare è più piccolo.
# indovina il numero (1-100): 90
# Bravo! Hai indovinato il numero 90 in 7 tentativi.

# %% [markdown]
# ##### ROULETTE RUSSA

# %%
import random
P=random.randint(1, 6)

scelta_del_giocatore=input("scegli un numero da 1 a 6: ")
while scelta_del_giocatore!="1" and scelta_del_giocatore!="2" and scelta_del_giocatore!="3"and scelta_del_giocatore!="4"and scelta_del_giocatore!="5"and scelta_del_giocatore!="6":
    print("ho detto un numero da 1 a 6")
    scelta_del_giocatore=input("scegli un numero da 1 a 6: ")

punteggio=0
while True:
    scelta_del_giocatore=int(input("metti un numero da 1 a 6: "))
    punteggio+=1

    if P==scelta_del_giocatore:
        print("Bang! mission failed")
        break
    else:
        print("click, non succede niente")

print("hai fatto un punteggio di ", punteggio)

# %% [markdown]
# ###

# %% [markdown]
#  #### Morra Cinese

# %%
import random
c_f_s=["carta", "forbice", "sasso"]
scelta_computer=random.choice(c_f_s)

scelta_del_giocatore=input("carta forbice sasso! ")
while scelta_del_giocatore!="carta" and scelta_del_giocatore!="forbice" and scelta_del_giocatore!="sasso":
    print("stiamo giocando a carta forbice sasso non a", scelta_del_giocatore, "melone Giuseppe")
    scelta_del_giocatore=input("carta forbice sasso! ")

print("io ho scelto", scelta_computer)

if scelta_computer=="carta" and scelta_del_giocatore=="forbice":
    print("hai vinto questa volta ma non vincerai di nuovo")
elif scelta_computer=="forbice" and scelta_del_giocatore=="carta":
    print("ha ha, suka hai perso")
elif scelta_computer=="forbice" and scelta_del_giocatore=="sasso":
    print("hai vinto questa volta ma non vincerai di nuovo")
elif scelta_computer=="sasso" and scelta_del_giocatore=="forbice":
    print("ha ha, suka hai perso")
elif scelta_computer=="sasso" and scelta_del_giocatore=="carta":
    print("hai vinto questa volta ma non vincerai di nuovo")
elif scelta_computer=="carta" and scelta_del_giocatore=="sasso":
    print("ha ha, suka hai perso")
else:
    print("Pareggio... ti odio")
# Out:
# carta forbice sasso! carta
# io ho scelto carta
# Pareggio... ti odio

# %% [markdown]
# #### Fattoriale

# %%
n=int(input("inserisci numero:"))

fattoriale=1

if n<0:
    print("aspetta... solo numeri positivi")
    
elif n==0:
    print("cojone deve essere un numero intero")
    
else:
    for numero in range(1,1+n):
        fattoriale*=numero

print(f"il numero fattoriale di {n} è {fattoriale}")
# Out:
# inserisci numero:4
# il numero fattoriale di 4 è 24

# %% [markdown]
# #### UGA ROULETTE DA SOLO

# %%
import random
P=random.randint(1, 8)

scelta_del_giocatore=int(input("scegli un numero da 1 a 8: "))
 
while True:
    if scelta_del_giocatore<1 or scelta_del_giocatore>8:
        print("scelta errata")
        break
    elif scelta_del_giocatore==P:
        print("Bang! sei morto")
        break
    else:
        print("sei vivo")
        print("il proiettile era nel",P,"slot")
        continuare=input("per continuare a giocare premi 1: ")
        if continuare=="1":
            P=random.randint(1, 8)
            scelta_del_giocatore=int(input("scegli un numero da 1 a 8: "))
            if scelta_del_giocatore<1 or scelta_del_giocatore>8:
                print("scelta errata")
                break
        else:
            break

# %% [markdown]
# #### UGA ROULETTE PVE

# %%
import random
P=random.randint(1, 8)

scelta_del_giocatore=int(input("scegli un numero da 1 a 8: "))
scelta_del_computer=random.randint(1, 8)
while True:
    if scelta_del_giocatore<1 or scelta_del_giocatore >8:
        print("scelta errata")
        break
    elif scelta_del_computer==scelta_del_giocatore:
        scelta_del_computer=random.randint(1,8)
    elif scelta_del_giocatore==P:
        print("Bang! sei morto")
        break
    elif scelta_del_computer==P:
        print("il computer ha scelto",scelta_del_computer)
        print("il proiettile è nel",P,"slot")
        print("hai vinto")
        break
    else:
        print("il computer ha scelto",scelta_del_computer)
        print("il proiettile era nel",P,"slot")
        print("siete sopravvisuti entrambi")
        continuare=input("per continuare a giocare premi 1: ")
        if continuare=="1":
            P=random.randint(1, 8)
            scelta_del_giocatore=int(input("scegli un numero da 1 a 8: "))
            scelta_del_computer=P=random.randint(1, 8)
            if scelta_del_giocatore<1 or scelta_del_giocatore>8:
                print("scelta errata")
                break
        else:
            break
# Out:
# scegli un numero da 1 a 8: 2
# il computer ha scelto 5
# il proiettile era nel 6 slot
# siete sopravvisuti entrambi
# per continuare a giocare premi 1: 1
# scegli un numero da 1 a 8: 4
# il computer ha scelto 8
# il proiettile è nel 8 slot
# hai vinto

# %%
frase = input("inserisci una farse ").lower()

CV = 0

V = "aeiouèéòàù"

for carattere in frase:
    if carattere in V:
        CV += 1
        
#la f prima delle "" serve per rendere la "" piu flessibile e inserire variabili come CV
print(f"nella frase ci sono {CV} vocali.")
# Out:
# inserisci una farse uga è a casa
# nella frase ci sono 6 vocali.

# %% [markdown]
# ...

# %% [markdown]
# DOPO DUE SETTIMANE DI ATTESA...

# %%
import random

numero_dado = random.randint(1,6)

indovina = int(input("metti un numero da 1 a 6 "))
if indovina<1 or indovina >6:
    print("cojone metti un numero da 1 a 6 ")
elif indovina == numero_dado:
    print("HAI VINTO!")
        
else:
    print("HAI PERSO XD")
# Out:
# metti un numero da 1 a 6 3
# HAI PERSO XD

# %%
popolazione = int(input("inserisce una popolazione iniziale: "))
anni = int(input("inserisci numero di anni di simulazione "))

tasso_nascite = float(input("inserisci tasso natalità "))
tasso_morte = float(input("inserisci tasso di mortalità "))


for anno in range(anni):
    nascite = (popolazione * tasso_nascite / 100)
    morti = (popolazione * tasso_morte / 100)
    popolazione += (nascite - morti)
    
    print(f"Anno{anno+1}: Popolazione = {int(popolazione)}")

print("Simulazione completata.")
# Out:
# inserisce una popolazione iniziale: 2
# inserisci numero di anni di simulazione 100
# inserisci tasso natalità 15
# inserisci tasso di mortalità 1
# Anno1: Popolazione = 2
# Anno2: Popolazione = 2
# Anno3: Popolazione = 2
# Anno4: Popolazione = 3
# Anno5: Popolazione = 3
# Anno6: Popolazione = 4
# Anno7: Popolazione = 5
# Anno8: Popolazione = 5
# Anno9: Popolazione = 6
# Anno10: Popolazione = 7
# Anno11: Popolazione = 8
# Anno12: Popolazione = 9
# Anno13: Popolazione = 10
# Anno14: Popolazione = 12
# Anno15: Popolazione = 14
# Anno16: Popolazione = 16
# Anno17: Popolazione = 18
# Anno18: Popolazione = 21
# Anno19: Popolazione = 24
# Anno20: Popolazione = 27
# Anno21: Popolazione = 31
# Anno22: Popolazione = 35
# Anno23: Popolazione = 40
# Anno24: Popolazione = 46
# Anno25: Popolazione = 52
# Anno26: Popolazione = 60
# Anno27: Popolazione = 68
# Anno28: Popolazione = 78
# Anno29: Popolazione = 89
# Anno30: Popolazione = 101
# Anno31: Popolazione = 116
# Anno32: Popolazione = 132
# Anno33: Popolazione = 150
# Anno34: Popolazione = 172
# Anno35: Popolazione = 196
# Anno36: Popolazione = 223
# Anno37: Popolazione = 254
# Anno38: Popolazione = 290
# Anno39: Popolazione = 331
# Anno40: Popolazione = 377
# Anno41: Popolazione = 430
# Anno42: Popolazione = 490
# Anno43: Popolazione = 559
# Anno44: Popolazione = 638
# Anno45: Popolazione = 727
# Anno46: Popolazione = 829
# Anno47: Popolazione = 945
# Anno48: Popolazione = 1077
# Anno49: Popolazione = 1228
# Anno50: Popolazione = 1400
# Anno51: Popolazione = 1596
# Anno52: Popolazione = 1820
# Anno53: Popolazione = 2074
# Anno54: Popolazione = 2365
# Anno55: Popolazione = 2696
# Anno56: Popolazione = 3073
# Anno57: Popolazione = 3504
# Anno58: Popolazione = 3994
# Anno59: Popolazione = 4554
# Anno60: Popolazione = 5191
# Anno61: Popolazione = 5918
# Anno62: Popolazione = 6747
# Anno63: Popolazione = 7691
# Anno64: Popolazione = 8768
# Anno65: Popolazione = 9996
# Anno66: Popolazione = 11395
# Anno67: Popolazione = 12991
# Anno68: Popolazione = 14810
# Anno69: Popolazione = 16883
# Anno70: Popolazione = 19247
# Anno71: Popolazione = 21941
# Anno72: Popolazione = 25013
# Anno73: Popolazione = 28515
# Anno74: Popolazione = 32507
# Anno75: Popolazione = 37059
# Anno76: Popolazione = 42247
# Anno77: Popolazione = 48161
# Anno78: Popolazione = 54904
# Anno79: Popolazione = 62591
# Anno80: Popolazione = 71353
# Anno81: Popolazione = 81343
# Anno82: Popolazione = 92731
# Anno83: Popolazione = 105714
# Anno84: Popolazione = 120514
# Anno85: Popolazione = 137385
# Anno86: Popolazione = 156619
# Anno87: Popolazione = 178546
# Anno88: Popolazione = 203543
# Anno89: Popolazione = 232039
# Anno90: Popolazione = 264524
# Anno91: Popolazione = 301558
# Anno92: Popolazione = 343776
# Anno93: Popolazione = 391905
# Anno94: Popolazione = 446772
# Anno95: Popolazione = 509320
# Anno96: Popolazione = 580624
# Anno97: Popolazione = 661912
# Anno98: Popolazione = 754580
# Anno99: Popolazione = 860221
# Anno100: Popolazione = 980652
# Simulazione completata.

# %% [markdown]
# #

# %% [markdown]
# ## Ez

# %%
import datetime 

today = datetime.datetime.today()
print(f"oggi è il giorno: {today:%d %m %Y} ore: {today: %H %M %S}")
# Out:
# oggi è il giorno: 18 10 2023 ore:  12 29 48

# %% [markdown]
# ### Fibonacci

# %%
n = int(input("inserisci un numero da calcolare "))

a=0
b=1
c=a+b

if n <= 0:
    print("NO")
    
elif n == 1:
    risultato = a
    
else:
    for interazione in range(n+3):
        a=b
        b=c
        c=a+b
        risultato = c
        

print(f"il {n} numero della serie di fibonacci è ", risultato)
# Out:
# inserisci un numero da calcolare 5
# il 5 numero della serie di fibonacci è  55

# %%
from itertools import permutations
k=0

def trova_anagrammi(parola):
    anagrammi=["".join<(p) for p in permutation(parola)]
    return anagrammi

# %% [markdown]
#  ## Grafici vari

# %%
import matplotlib.pyplot as plt
animali = ['Elefanti', 'Leoni', 'Tigri', 'Scimmie', 'Zebre']
numero_animali = [4, 3, 2, 8, 15]

plt.bar(animali,numero_animali, color='skyblue')
plt.title('numero di animali di uno zoo')
plt.xlabel('animali')
plt.ylabel('numero')
plt.show()

# %%
import matplotlib.pyplot as plt
animali=['Elefanti','Leoni','Tigri','Scimmie','Zebre','Leocorni']
numero_animali=[4, 3, 2, 8, 15, 0]
plt.bar(animali, numero_animali, color="Lightblue")
plt.show()

# %%
nomi_studenti=['obeso1' ,'obeso2' ,'obeso3' ,'obeso4']
punteggi = [15 ,69 ,96 ,18]

plt.barh(nomi_studenti,punteggi, color='green')
plt.title('Punteggi studenti')
plt.xlabel('Punteggi')
plt.ylabel('Studenti')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

nomi_studenti = ['Alice', 'Bob', 'Charlie', 'David', 'Eve']
punteggi = [85, 92, 78, 88, 95]

# Crea un DataFrame con nomi e punteggi
data = {'Nome dello Studente': nomi_studenti, 'Punteggio': punteggi}
df = pd.DataFrame(data)

df.sort_values(by='Punteggio', inplace=True)
df

plt.barh(nomi_studenti,punteggi, color='green')
plt.title('Punteggi studenti')
plt.xlabel('Punteggi')
plt.ylabel('Studenti')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

altezza_maschi = np.random.normal(175, 10, 50)  # Altezza dei maschi
peso_maschi = np.random.normal(70, 5, 50)  # Peso dei maschi

altezza_femmine = np.random.normal(162, 8, 50)  # Altezza delle femmine
peso_femmine = np.random.normal(58, 4, 50)  # Peso delle femmine

plt.plot(altezza_maschi,peso_maschi, color='blue', label='Maschi', marker='o', linestyle='--')
plt.plot(altezza_femmine,peso_femmine, color='pink', label='Femmine', marker='s', linestyle='--')
plt.title('Grafico a Dispersione Altezza vs Peso')
plt.xlabel('Altezza (cm)')
plt.ylabel('Peso (kg)')
plt.legend(loc='upper left')
plt.gris(true)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 16
#      14 plt.ylabel('Peso (kg)')
#      15 plt.legend(loc='upper left')
# ---> 16 plt.gris(true)
#      17 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'gris'

# %%
import matplotlib.pyplot as plt
import numpy as np
materie = ['Matematica', 'Scienze', 'Inglese', 'Storia', 'Arte']
maschi = [30, 25, 35, 20, 15]  # Numero di studenti maschi per materia
femmine = [20, 30, 25, 15, 10]  # Numero di studentesse per materia
plt.figure(figsize=(20, 34))
plt.bar(materie, maschi, label='Maschi', color='blue')
plt.bar(materie, femmine, label='Femmine', bottom=maschi, color='pink')
plt.title('Grafico a barre ampliato per materia e sesso')
plt.xlabel('Materie')
plt.ylabel('Numero di Studenti')
plt.legend(loc='upper right')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# Genera dati di esempio
data = {
    'Variable1': [1, 2, 3, 4, 5],
    'Variable2': [1, 2, np.nan, 4, np.nan],
    'Missing_Column': ['A', 'B', 'A', 'C', np.nan]
}
# Crea un DataFrame
df = pd.DataFrame(data)
df1=pd.DataFrame()
df
# Out:
#    Variable1  Variable2 Missing_Column
# 0          1        1.0              A
# 1          2        2.0              B
# 2          3        NaN              A
# 3          4        4.0              C
# 4          5        NaN            NaN

# %%
import pandas as pd

# Dataset con dati mancanti rappresentati da None o NaN
dataset = [
    {"nome": "Alice", "età": 25, "punteggio": 90, "email": "alice@email.com"},
    {"nome": "Bob", "età": 22, "punteggio": None, "email": None},
    {"nome": "Charlie", "età": 28, "punteggio": 75, "email": "charlie@email.com"},
]

# Converti il dataset in un DataFrame
df = pd.DataFrame(dataset)
df
# Out:
#       nome  età  punteggio              email
# 0    Alice   25       90.0    alice@email.com
# 1      Bob   22        NaN               None
# 2  Charlie   28       75.0  charlie@email.com

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# Genera dati di esempio
data = {
    'Variable1': [1, 2, 3, 4, 5],
    'Variable2': [1, 2, np.nan, 4, np.nan],
    'Missing_Column': ['A', 'B', 'A', 'C', np.nan]
}
# Crea un DataFrame
df = pd.DataFrame(data)
df1=pd.DataFrame()
df
# Out:
#    Variable1  Variable2 Missing_Column
# 0          1        1.0              A
# 1          2        2.0              B
# 2          3        NaN              A
# 3          4        4.0              C
# 4          5        NaN            NaN

# %%
categorical_cols = df.select_dtypes(exclude=['number'])
categorical_cols.columns
# Out:
# Index(['Missing_Column'], dtype='object')

# %%
print(f"il primo con i valori mancanti \n{df} \ne il secondo con il missing values sostitutivi \n{df1}")
# Out:
# il primo con i valori mancanti
#    Variable1  Variable2 Missing_Column
# 0          1        1.0              A
# 1          2        2.0              B
# 2          3        NaN              A
# 3          4        4.0              C
# 4          5        NaN            NaN
# e il secondo con il missing values sostitutivi
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Genera dati di esempio
data = {
    'Feature1': [1, 2, np.nan, 4, 5],
    'Feature2': [np.nan, 2, 3, 4, np.nan],
    'Feature3': [1, np.nan, 3, 4, 5]
}
# Crea un DataFrame
df = pd.DataFrame(data)
df
# Out:
#    Feature1  Feature2  Feature3
# 0       1.0       NaN       1.0
# 1       2.0       2.0       NaN
# 2       NaN       3.0       3.0
# 3       4.0       4.0       4.0
# 4       5.0       NaN       5.0

# %%
df.isnull()
# Out:
#    Feature1  Feature2  Feature3
# 0     False      True     False
# 1     False     False      True
# 2      True     False     False
# 3     False     False     False
# 4     False      True     False

# %%
df.isnull().sum()
# Out:
# Feature1    1
# Feature2    2
# Feature3    1
# dtype: int64

# %%
missing_percent = (df.isnull().sum() / len(df)) * 100
missing_percent
# Out:
# Feature1    20.0
# Feature2    40.0
# Feature3    20.0
# dtype: float64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Genera dati di esempio
data = {
    'Feature1': [1, 2, np.nan, 4, 5],
    'Feature2': [np.nan, 2, 3, 4, np.nan],
    'Feature3': [1, np.nan, 3, 4, 5]
}

# Crea un DataFrame
df = pd.DataFrame(data)

# Calcola la matrice di missing values
missing_matrix = df.isnull()
missing_matrix
# Out:
#    Feature1  Feature2  Feature3
# 0     False      True     False
# 1     False     False      True
# 2      True     False     False
# 3     False     False     False
# 4     False      True     False

# %%
plt.figure(figsize=(10, 6))
missing_percent.plot(kind='bar', color='red', alpha=0.8)
plt.xlabel('Variabili')
plt.ylabel('Percentuale di missing faluable')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 missing_percent.plot(kind='bar', color='red', alpha=0.8)
#       3 plt.xlabel('Variabili')
#       4 plt.ylabel('Percentuale di missing faluable')
#
# NameError: name 'missing_percent' is not defined

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(missing_matrix, cmap='virdis', cbar=True, alpha=0.8)
plt.title('CCKE')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 plt.figure(figsize=(8, 6))
# ----> 2 sns.heatmap(missing_matrix, cmap='virdis', cbar=True, alpha=0.8)
#       3 plt.title('CCKE')
#       4 plt.show()
#
# NameError: name 'missing_matrix' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Genera dati casuali per l'esplorazione
np.random.seed(69)
data = {
    'Età': np.random.randint(18, 70, size=1000),
    'Genere': np.random.choice(['Maschio', 'Femmina'], size=1000),
    'Punteggio': np.random.uniform(0, 100, size=1000),
    'Reddito': np.random.normal(50000, 15000, size=1000)
}

df = pd.DataFrame(data)

# Visualizza le prime righe del dataset
print(df.head())
# Out:
#    Età   Genere  Punteggio       Reddito
# 0   29  Femmina  13.310383  60229.618598
# 1   27  Femmina  20.931467  63176.492680
# 2   61  Maschio  58.034146  37654.926212
# 3   44  Maschio  78.934515  35460.577367
# 4   38  Femmina  80.920850  15735.770948

# %%
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")
sns.histplot(df["Reddito"], kde=False, bins=30, label="Reddito")
plt.legend
plt.title('banane')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plt.figure(figsize=(12, 6))
#       2 sns.set_style("whitegrid")
#       3 sns.histplot(df["Reddito"], kde=False, bins=30, label="Reddito")
#
# NameError: name 'plt' is not defined

# %%
numeric_features = df.select_dtypes(include=[np.number])
sns.pairplot(df[numeric_features.columns])
plt.title(' Titolo ')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 numeric_features = df.select_dtypes(include=[np.number])
#       2 sns.pairplot(df[numeric_features.columns])
#       3 plt.title(' Titolo ')
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x= 'Genere', y= 'Punteggio', data=df)
plt.title('Box plot tra genere e punteggio')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.figure(figsize=(10, 6))
#       2 sns.boxplot(x= 'Genere', y= 'Punteggio', data=df)
#       3 plt.title('Box plot tra genere e punteggio')
#
# NameError: name 'plt' is not defined

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\matti\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\matti\anaconda3\lib\site-packages (from plotly) (8.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px
fig=px.scatter(df, x='Età', y='Reddito', color='Genere', size='Punteggio')
fig.update_layout(title='Grafico a dispersione interattivo')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 import plotly.express as px
# ----> 2 fig=px.scatter(df, x='Età', y='Reddito', color='Genere', size='Punteggio')
#       3 fig.update_layout(title='Grafico a dispersione interattivo')
#       4 fig.show()
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_chart_types.py:66, in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_options, trendline_color_override, trendline_scope, log_x, log_y, range_x, range_y, render_mode, title, template, width, height)
#      12 def scatter(
#      13     data_frame=None,
#      14     x=None,
#    (...)
#      60     height=None,
#      61 ) -> go.Figure:
#      62     """
#      63     In a scatter plot, each row of `data_frame` is represented by a symbol
#      64     mark in 2D space.
#      65     """
# ---> 66     return make_figure(args=locals(), constructor=go.Scatter)
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_core.py:1990, in make_figure(args, constructor, trace_patch, layout_patch)
#    1987 layout_patch = layout_patch or {}
#    1988 apply_default_cascade(args)
# -> 1990 args = build_dataframe(args, constructor)
#    1991 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1992     args = process_dataframe_hierarchy(args)
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_core.py:1405, in build_dataframe(args, constructor)
#    1402     args["color"] = None
#    1403 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1405 df_output, wide_id_vars = process_args_into_dataframe(
#    1406     args, wide_mode, var_name, value_name
#    1407 )
#    1409 # now that `df_output` exists and `args` contains only references, we complete
#    1410 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1411 # df_output
#    1413 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_core.py:1207, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1205         if argument == "index":
#    1206             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1207         raise ValueError(err_msg)
#    1208 elif length and len(df_input[argument]) != length:
#    1209     raise ValueError(
#    1210         "All arguments should have the same length. "
#    1211         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1218         )
#    1219     )
#
# ValueError: Value of 'x' is not the name of a column in 'data_frame'. Expected one of ['Feature1', 'Feature2', 'Feature3'] but received: Età

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Genera dati casuali per l'esplorazione
np.random.seed(22)
data = {
    'Data': pd.date_range(start='2023-01-01', end='2023-12-31', freq='D'),
    'Vendite': np.random.randint(100, 1000, size=365),
    'Prodotto': np.random.choice(['A', 'B', 'C'], size=365)
}

df = pd.DataFrame(data)

# Visualizza le prime righe del dataset
print(df.head())

# Visualizza un grafico delle vendite nel tempo
plt.figure(figsize=(12, 6))
sns.lineplot(x='Data', y='Vendite', data=df)
plt.title('Andamento delle vendite nel tempo')
plt.xlabel('Data')
plt.ylabel('Vendite')
plt.xticks(rotation=45)
plt.show()

# Visualizza una box plot delle vendite per prodotto
plt.figure(figsize=(10, 6))
sns.boxplot(x='Prodotto', y='Vendite', data=df)
plt.title('Box Plot delle vendite per prodotto')
plt.xlabel('Prodotto')
plt.ylabel('Vendite')
plt.show()
# Out:
#         Data  Vendite Prodotto
# 0 2023-01-01      985        C
# 1 2023-01-02      232        B
# 2 2023-01-03      912        C
# 3 2023-01-04      456        B
# 4 2023-01-05      458        A

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Genera dati di esempio
data = {
    'Numeric_Var': [1, 2, 3, 4, np.nan, 6],
    'Categorical_Var': ['A', 'B', 'A', 'B', 'A', 'B']
}

# Crea un DataFrame
df = pd.DataFrame(data)
print(df)
# Out:
#    Numeric_Var Categorical_Var
# 0          1.0               A
# 1          2.0               B
# 2          3.0               A
# 3          4.0               B
# 4          NaN               A
# 5          6.0               B

# %%
conditional_means = df['Numeric_Var'].fillna(df.groupby('Categorical_Var')['Numeric_Var'].transform('mean'))
conditional_means
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    2.0
# 5    6.0
# Name: Numeric_Var, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Genera dati casuali per l'esplorazione
np.random.seed(42)
data = {
    'Età': np.random.randint(18, 65, size=500),
    'Soddisfazione': 
    np.random.choice(['Molto Soddisfatto', 'Soddisfatto', 'Neutro', 'Insoddisfatto', 'Molto Insoddisfatto'], size=500)
}

df = pd.DataFrame(data)
print(df)
conditional_means = df.groupby('Soddisfazione')['Età'].transform('mean')

df['Numeric_Var'] = conditional_means
print(df)

# Crea un grafico a barre per mostrare la media condizionata per ogni categoria
plt.figure(figsize=(8, 6))
sns.barplot(data=df, x='Soddisfazione', y='Numeric_Var', errorbar=None)
plt.xlabel('Soddisfazione')
plt.ylabel('Media Condizionata di Numeric_Var')
plt.title('Media Condizionata delle Variabili Numeriche per Categoria')
plt.xticks(rotation=90)

plt.show()
# Out:
#      Età        Soddisfazione
# 0     56    Molto Soddisfatto
# 1     46  Molto Insoddisfatto
# 2     32               Neutro
# 3     60               Neutro
# 4     25  Molto Insoddisfatto
# ..   ...                  ...
# 495   37    Molto Soddisfatto
# 496   41    Molto Soddisfatto
# 497   29    Molto Soddisfatto
# 498   52    Molto Soddisfatto
# 499   50    Molto Soddisfatto
#
# [500 rows x 2 columns]
#      Età        Soddisfazione  Numeric_Var
# 0     56    Molto Soddisfatto    41.651376
# 1     46  Molto Insoddisfatto    40.054054
# 2     32               Neutro    41.747368
# 3     60               Neutro    41.747368
# 4     25  Molto Insoddisfatto    40.054054
# ..   ...                  ...          ...
# 495   37    Molto Soddisfatto    41.651376
# 496   41    Molto Soddisfatto    41.651376
# 497   29    Molto Soddisfatto    41.651376
# 498   52    Molto Soddisfatto    41.651376
# 499   50    Molto Soddisfatto    41.651376
#
# [500 rows x 3 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Visualizza le prime righe del dataset
print(df.head())

# Visualizza una distribuzione dell'età
plt.figure(figsize=(10, 6))
sns.histplot(df['Età'], bins=50, kde=True)
plt.title('Distribuzione dell\'età dei partecipanti al sondaggio')
plt.xlabel('Età')
plt.ylabel('Conteggio')
plt.show()

# Visualizza un conteggio delle risposte sulla soddisfazione
plt.figure(figsize=(8, 6))
sns.countplot(x='Soddisfazione', data=df, order=['Molto Soddisfatto', 'Soddisfatto', 'Neutro', 'Insoddisfatto', 'Molto Insoddisfatto'])
plt.title('Conteggio delle risposte sulla soddisfazione')
plt.xlabel('Soddisfazione')
plt.ylabel('Conteggio')
plt.xticks(rotation=45)
plt.show()
# Out:
#    Età        Soddisfazione  Numeric_Var
# 0   56    Molto Soddisfatto    41.651376
# 1   46  Molto Insoddisfatto    40.054054
# 2   32               Neutro    41.747368
# 3   60               Neutro    41.747368
# 4   25  Molto Insoddisfatto    40.054054

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(69)
data= DataFrame(np.random.rand(100, 5), culumns['Var1', 'Var2', 'Var3', 'Var4', 'Var5'])

data=[Categorical_var]

# %%
numeric_colors = df.select_dtypes(include=['numbar'])
categorical_cols = df.selct_dtypes(exlude=['number'])

df.loc[:, categorical_cols.columns] = df[categorical_cols.columns].fillna(df[categorical__cols.columns].mode().ilopc[0])

conditional_means = df[numeric_cols.columns].fillna(df-groupby)

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\matti\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\matti\anaconda3\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\matti\anaconda3\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\matti\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\matti\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Creare dati casuali per altezze (variabile indipendente) e pesi (variabile dipendente)
np.random.seed(0)
altezze = np.random.normal(160, 10, 100)
pesi = 0.5 * altezze + np.random.normal(0, 5, 100)

# Suddividere il dataset in training set (70%) e test set (30%)
X_train, X_test, y_train, y_test = train_test_split(altezze, pesi, test_size=0.3, random_state=42)

# Stampare le dimensioni dei training set e test set
print("Dimensioni del Training Set (altezze e pesi):", X_train.shape, y_train.shape)
print("Dimensioni del Test Set (altezze e pesi):", X_test.shape, y_test.shape)
# Out:
# Dimensioni del Training Set (altezze e pesi): (70,) (70,)
# Dimensioni del Test Set (altezze e pesi): (30,) (30,)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Creazione di dati casuali per visite al sito web e importo delle vendite
np.random.seed(0)
visite_al_sito = np.random.randint(100, 1000, 1000)
importo_vendite = 50 + 0.2 * visite_al_sito + np.random.normal(0, 10, 1000)

# Suddivisione del dataset in training set (70%) e test set (30%)
X_train, X_test, y_train, y_test = train_test_split(visite_al_sito, importo_vendite, test_size=0.3, random_state=42)

# Creazione di un grafico a dispersione
plt.figure(figsize=(10, 6))
plt.scatter(X_train, y_train, label='Training Set', color='blue', alpha=0.7)
plt.scatter(X_test, y_test, label='Test Set', color='orange', alpha=0.7)
plt.xlabel('Numero di Visite al Sito')
plt.ylabel('Importo delle Vendite')
plt.title('Relazione tra Visite al Sito e Importo delle Vendite')
plt.legend()
plt.grid(True)
plt.show()

# Stampare le dimensioni dei training set e test set
print("Dimensioni del Training Set (visite al sito e importo delle vendite):", X_train.shape, y_train.shape)
print("Dimensioni del Test Set (visite al sito e importo delle vendite):", X_test.shape, y_test.shape)
# Out:
# Dimensioni del Training Set (visite al sito e importo delle vendite): (700,) (700,)
# Dimensioni del Test Set (visite al sito e importo delle vendite): (300,) (300,)

# %%
from sklearn.model_selection import train_test_split
import numpy as np

np.random.seed(1)
# Supponiamo di avere un dataset con feature X e target y
X = np.random.rand(100, 2)  # Dati del dataset (100 campioni, 2 feature)
y = np.random.choice(['A', 'B'], size=100)  # Etichette di classe casuali
# Calcola le proporzioni delle classi nel dataset originale
proporzione_classe_A = sum(y == 'A') / len(y)
proporzione_classe_B = 1 - proporzione_classe_A
# Eseguire uno split stratificato con una proporzione specificata
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Calcola le proporzioni delle classi nel training set e nel test set
proporzione_classe_A_train = sum(y_train == 'A') / len(y_train)
proporzione_classe_B_train = 1 - proporzione_classe_A_train

proporzione_classe_A_test = sum(y_test == 'A') / len(y_test)
proporzione_classe_B_test = 1 - proporzione_classe_A_test

# Stampa delle proporzioni
print("Proporzione Classe A nel data Set completo:", proporzione_classe_A)
print("Proporzione Classe B nel data Setcompleto:", proporzione_classe_B)
print("Proporzione Classe A nel Training Set:", proporzione_classe_A_train)
print("Proporzione Classe B nel Training Set:", proporzione_classe_B_train)
print("Proporzione Classe A nel Test Set:", proporzione_classe_A_test)
print("Proporzione Classe B nel Test Set:", proporzione_classe_B_test)
# Out:
# Proporzione Classe A nel data Set completo: 0.54
# Proporzione Classe B nel data Setcompleto: 0.45999999999999996
# Proporzione Classe A nel Training Set: 0.5285714285714286
# Proporzione Classe B nel Training Set: 0.4714285714285714
# Proporzione Classe A nel Test Set: 0.5666666666666667
# Proporzione Classe B nel Test Set: 0.43333333333333335

# %%
labels = ['Classe A', 'Classe B']

colors = ['gold', 'red']

plt.pie([proporzione_classe_A, proporzione_classe_B], labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('Proporzione delle classi nel Set')
plt.show()

# %%
labels = ['Classe A', 'Classe B']

colors = ['gold', 'red']

plt.pie([proporzione_classe_A_train, proporzione_classe_B_train], labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('Proporzione delle classi nel Set TRAIN')
plt.show()

# %%
labels = ['Classe A', 'Classe B']

colors = ['gold', 'red']

plt.pie([proporzione_classe_A_test, proporzione_classe_B_test], labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('Proporzione delle classi nel Set TEST')
plt.show()

# %% [markdown]
# ## Calcolo del reddito

# %%
import random
import numpy as np


int campione

dataset=[]
# scelgo un minimo e massimo di salario e in più scelgo quante persone considerare
popolazione_attiva = 24000000
for i in range(popolazione_attiva):
    dataset.append(random.randint(0, 1000000))

# Estrazione di un campione casuale semplice di 300 elementi dal dataset
campione_casuale = random.sample(dataset, 0.3 * popolazione_attiva)

# Calcolo della media e della deviazione standard del campione
media_campione = np.mean(campione_casuale)
deviazione_standard_campione = np.std(campione_casuale)

# Calcolo della media e della deviazione standard del dataset completo
media_dataset = np.mean(dataset)
deviazione_standard_dataset = np.std(dataset)

#Printo il risultato utilizando la f prima delle "" in modo da renderlo flessibili e aggiungere funzioni senza dover aprire 
#e chiudere le parentesi
print(f"Media del campione casuale: {media_campione: .2f}")
print(f"Deviazione standard del campione casuale: {deviazione_standard_campione: .2f}")
print(f"Media del dataset completo: {media_dataset: .2f}")
print(f"Deviazione standard del dataset completo: {deviazione_standard_dataset: .2f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       8     dataset.append(random.randint(0, 1000000))
#      10 # Estrazione di un campione casuale semplice di 300 elementi dal dataset
# ---> 11 campione_casuale = random.sample(dataset, 0.3 * popolazione_attiva)
#      13 # Calcolo della media e della deviazione standard del campione
#      14 media_campione = np.mean(campione_casuale)
#
# File ~\anaconda3\Lib\random.py:457, in Random.sample(self, population, k, counts)
#     455 if not 0 <= k <= n:
#     456     raise ValueError("Sample larger than population or is negative")
# --> 457 result = [None] * k
#     458 setsize = 21        # size of a small set minus size of an empty list
#     459 if k > 5:
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %% [markdown]
# #### Splitto in due il data set per addestrare e creare una macchina che agiona in base a un allenamento precedentemente programmato.
#
# Traning set serve per addestrare la macchina.
#
# Il Test serve per vedere se quello che ha imparato ne traning.

# %% [markdown]
# #
